# %%
import torch
import torchvision.transforms.v2 as transforms
from torchvision import models
from torchvision.models.feature_extraction import get_graph_node_names
from torchvision.models.feature_extraction import create_feature_extractor
import pickle
import numpy as np
import firebase_admin
from firebase_admin import credentials, firestore,storage
import requests
from PIL import Image, UnidentifiedImageError
from io import BytesIO
import tempfile
import os

# %%
if not firebase_admin._apps:
    cred = credentials.Certificate("imagequest-aab50-firebase-adminsdk-fbsvc-44dd473055.json")
    firebase_admin.initialize_app(cred, {"storageBucket": "imagequest-aab50.firebasestorage.app"})
db = firestore.client()
bucket = storage.bucket()

# %%
model = models.vgg16(weights=models.VGG16_Weights.DEFAULT)
model.eval()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
train_nodes, eval_nodes = get_graph_node_names(model)
print(train_nodes)
print(eval_nodes)
# Out:
# ['x', 'features.0', 'features.1', 'features.2', 'features.3', 'features.4', 'features.5', 'features.6', 'features.7', 'features.8', 'features.9', 'features.10', 'features.11', 'features.12', 'features.13', 'features.14', 'features.15', 'features.16', 'features.17', 'features.18', 'features.19', 'features.20', 'features.21', 'features.22', 'features.23', 'features.24', 'features.25', 'features.26', 'features.27', 'features.28', 'features.29', 'features.30', 'avgpool', 'flatten', 'classifier.0', 'classifier.1', 'classifier.2', 'classifier.3', 'classifier.4', 'classifier.5', 'classifier.6']
# ['x', 'features.0', 'features.1', 'features.2', 'features.3', 'features.4', 'features.5', 'features.6', 'features.7', 'features.8', 'features.9', 'features.10', 'features.11', 'features.12', 'features.13', 'features.14', 'features.15', 'features.16', 'features.17', 'features.18', 'features.19', 'features.20', 'features.21', 'features.22', 'features.23', 'features.24', 'features.25', 'features.26', 'features.27', 'features.28', 'features.29', 'features.30', 'avgpool', 'flatten', 'classifier.0', 'classifier.1', 'classifier.2', 'classifier.3', 'classifier.4', 'classifier.5', 'classifier.6']

# %%
data_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToImage(), 
    transforms.ToDtype(torch.float32, scale=True),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# %%
return_nodes = {
    'features.28': 'features.28', 
}
features = create_feature_extractor(model, return_nodes=return_nodes)
collection = db.collection('main2').stream(timeout=300)

# %%
extract = []
for x in collection:
    image = x.to_dict()
    image_url = image['url']
    image_id = image['image_id']
    try:
        get_image = requests.get(image_url, timeout=300)
        if get_image.status_code != 200:
            print("CANNOT GET IMAGE")
            continue

        read_image = Image.open(BytesIO(get_image.content)).convert('RGB')
        image_transform = data_transforms(read_image).unsqueeze(0)

        with torch.no_grad():
            output = features(image_transform)

        extraction = output['features.28'].cpu().numpy()
        reduce = extraction.reshape(1, -1)
        extract.append({
        'image_id': image_id,
        'url': image_url,
        'features': reduce.tolist()  
})

        print(f"FEATURES EXTRACTED: {image_id}: {reduce.shape}")
    except UnidentifiedImageError:
        print("UNIDENTIFIED IMAGE ERROR")
    except Exception as e:
        print("ERROR")
# Out:
# FEATURES EXTRACTED: chess_dataset2/00000021 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000030 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000086 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000007 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000072 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000002.JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000052.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000075 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000169.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000112.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000027.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000071 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000073.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000028 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000045.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000194 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000197 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000003 (3).JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000023.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000151 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000006.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000121 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000023.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000018 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000185.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000092.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000039 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000140.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000022 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000022.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000118 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000011.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000092 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000186 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000067.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000114 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000005.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000088 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000177 (4).JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000173.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000279.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000010 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000094 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000062 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000021 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000090.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000026 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000110.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000007 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000109.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000035.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000019 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000012 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000046 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000061 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000037.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000110 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000010 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000113 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000145 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000175 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000117 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000028 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000031 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000146.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000038.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000169 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000004 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000127.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000049.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000086 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000018 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000119.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000075 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000089.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000116.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000171.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000081.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000011 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000181.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000084.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000020 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000182 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000145.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000193.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000038 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000001.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000077.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000172.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000048 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000174.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000061 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000040.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000182 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000051 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000036 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000074 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000135 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000043 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000189 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000180.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000165.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000079 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000083 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000066.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000102.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000081 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000087.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000109 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000086.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000044 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000103.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000122 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000142 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000072 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000015 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000018.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000016 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000013 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000113 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000159.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000082.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000063.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000008 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000196 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000177 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000017 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000061 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000006 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000114 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000058 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000118 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000161.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000139.fcgi: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000043 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000042.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000098.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000076.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000109 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000010 (2).JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000045 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000150.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000113 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000126 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000199 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000162 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000013 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000068 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000145 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000050.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000175 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000026.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000095.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000056.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000154.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000167 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000106.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000151.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000079 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000195.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000116 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000116 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000157.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000002 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000019.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000069 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000000 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000039 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000025 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000192 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000021.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000139.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000029.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000167.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000175.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000079.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000020 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000058 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000071.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000001 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000163.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000001 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000070 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000097 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000020.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000053.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000072.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000010 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000082 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000102 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000026.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000012 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000106 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000084.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000104.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000030.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000037.jpeg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000127 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000069.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000144.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000013.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000017 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000037 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000200.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000123.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000012.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000109 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000113.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000199 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000054.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000070.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000167.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000196.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000124.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000094 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000192.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000035.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000031.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000156.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000130.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000025.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000126 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000005 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000062 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000043.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000078 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000075 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000170.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000214.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000096.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000005 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000119.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000128 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000040.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000136.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000026 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000178 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000066 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000032 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000107.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000120 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000074 (5).jpg: (1, 100352)
# UNIDENTIFIED IMAGE ERROR
# FEATURES EXTRACTED: chess_dataset2/00000042 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000195 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000168.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000131 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000057 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000177 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000099.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000058.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000173 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000192 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000009.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000008.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000095.gif: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000019.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000095 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000063 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000051.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000169 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000034 (2).JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000000 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000049 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000059.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000179.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000044 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000112 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000133 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000120.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000136 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000060 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000099 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000148.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000055.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000086.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000055 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000121.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000162.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000083.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000152.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000186.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000132.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000004 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000007 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000127 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000074 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000171 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000145.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000032 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000059 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000184.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000021.fcgi: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000135.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000013 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000009.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000134.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000047.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000003 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000003.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000196 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000081 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000011 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000072 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000032.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000008.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000035 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000154 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000068.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000006 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000199 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000064.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000232.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000137.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000058.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000015.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000134 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000197.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000128.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000114.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000017.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000006 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000011 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000033 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000017 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000054.jpeg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000173 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000137 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000117 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000119 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000002 (4).JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000195 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000012 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000146 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000177.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000075.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000039.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000023 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000082 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000188.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000074 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000114 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000046.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000149.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000087 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000065 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000136.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000048.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000113.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000060.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000005.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000025.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000065.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000102 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000115.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000088 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000056.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000122.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000031 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000030.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000068.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000049.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000112 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000127 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000126.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000064 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000120 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000004 (4).JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000147.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000031 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000088 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000042.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000024 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000221.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000158.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000027 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000101.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000066 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000094.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000166.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000097 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000028 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000187.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000155.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000085.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000008 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000098.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000197 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000060 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000025.jpeg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000019 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000139 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000183.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000099 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000076.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000050 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000170.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000014 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000086 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000044.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000088 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000037 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000084 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000014.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000151.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000073 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000197 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000149 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000167 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000010.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000025 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000189.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000198.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000065 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000014 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000131.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000101 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000015 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000036 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000022 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000160.webp: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000115 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000000.JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000108.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000001.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000179.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000076 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000117.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000071 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000134 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000057.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000016.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000097.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000182.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000112 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000000 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000199.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000088.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000097 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000165 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000027.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000019 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000089 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000080.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000193 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000066.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000024 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000142.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000013.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000084.jpeg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000163.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000116.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000121 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000167 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000071.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000180 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000056 (2).JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000041.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000098 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000049 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000111.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000172.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000007 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000125 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000219.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000004.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000126.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000017 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000041 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000121 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000031.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000141.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000085 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000063.jpeg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000021 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000190.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000129.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000078 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000085.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000043 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000022 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000160.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000051.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000016 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000028 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000193 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000176.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000077 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000138.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000178.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000007.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000059 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000130.jpeg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000124.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000064.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000204.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000003.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000044.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000170.php: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000079 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000118.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000078.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000194.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000143.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000024.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000032 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000060 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000132.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000174 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000141 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000032.jpeg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000138 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000022 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000015.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000094 (4).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000144.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000100.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000142 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000059 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000074.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000034.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000133.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000041 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000006 (2).JPG: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000067 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000036.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000028.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000037 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000015 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000103.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000012 (5).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000168 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000192 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000014.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000054 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000106.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000071 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000002 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000018 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000062.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000029 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000005 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000061.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000137 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000150 (2).png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000125.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000026 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000166.png: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000049 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000188.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000008 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000019 (3).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000107 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000033.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000164.jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000004 (2).jpg: (1, 100352)
# FEATURES EXTRACTED: chess_dataset2/00000034 (3).jpg: (1, 100352)

# %%
with tempfile.NamedTemporaryFile(delete=False, suffix='.pkl') as temp_file:
    pickle.dump(extract, temp_file)
    temp_filename = temp_file.name 
blob = bucket.blob("feature_vectors/vgg_features.pkl")
blob.upload_from_filename(temp_filename)
os.remove(temp_filename)
